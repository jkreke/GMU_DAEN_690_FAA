# %%
"""
Created on 1 April 2021
author: cjburrage

"""

# %%
import pandas as pd
df = pd.read_csv('/Users/Char/Desktop/laser_combined_05Apr.csv')
df.head(n=5)
# Out:
# /Users/Char/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (11,14,16,18,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                        X_id                      date callsign  \
# 0  5d2de0d02834ae4512fd68a7  2012-02-01T08:07:00.000Z  SKW4557
# 1  5d2de1612834ae4512fee420  2011-01-01T07:30:00.000Z   ASA328
# 2  5d2de1612834ae4512fee421  2011-01-01T09:50:00.000Z   HAL387
# 3  5d2de1612834ae4512fee43d  2011-01-01T05:02:00.000Z  UCA8737
# 4  5d2de1612834ae4512fee440  2011-01-01T06:14:00.000Z   NKS642
#
#                                     acType  \
# 0           CRJ2, CANADAIR, Challenger 800
# 1                    B734, BOEING, 737-400
# 2                    B712, BOEING, 717-200
# 3  DH8B, DE HAVILLAND CANADA, Dash 8 (200)
# 4                      A319, AIRBUS, A-319
#
# ...

# %%
df.shape
# Out:
# (51045, 47)

# %%
import re

# %%
#create new column with distance from landmark (airport or other) reported in remarks as NM

NM = ['NM']
df['Dist'] = df['remarks'].str.findall(r'[\d]+ (?i)\b(?:{})\b'.format('|'.join(NM))).apply(', '.join)

# %%
#check to make sure new column added
df.head()
# Out:
#                        X_id                      date callsign  \
# 0  5d2de0d02834ae4512fd68a7  2012-02-01T08:07:00.000Z  SKW4557
# 1  5d2de1612834ae4512fee420  2011-01-01T07:30:00.000Z   ASA328
# 2  5d2de1612834ae4512fee421  2011-01-01T09:50:00.000Z   HAL387
# 3  5d2de1612834ae4512fee43d  2011-01-01T05:02:00.000Z  UCA8737
# 4  5d2de1612834ae4512fee440  2011-01-01T06:14:00.000Z   NKS642
#
#                                     acType  \
# 0           CRJ2, CANADAIR, Challenger 800
# 1                    B734, BOEING, 737-400
# 2                    B712, BOEING, 717-200
# 3  DH8B, DE HAVILLAND CANADA, Dash 8 (200)
# 4                      A319, AIRBUS, A-319
#
#                                              remarks ncport orig.faa dest.faa  \
# 0   Aircraft illuminated by green laser whileE bo...    NaN      GRB      MSP
# 1   7 NM S SJC, San Jose, CA, heading E, 5,000 fe...    SJC      SJC      SEA
# 2   At 0446 the pilot reported a green laser eman...    HNL      HNL      KOA
# ...

# %%
#create separate columns to pull out #different ways they reported distance (note some reported as NM were not
# included in original "dist" column above, tried again, varying the regex pattern slighltly)
#these were later examined in excel

mile = ['mile']
df['mile'] = df['remarks'].str.findall(r'[\d]+ (?i)\b(?:{})\b'.format('|'.join(mile))).apply(', '.join)

miles = ['miles']
df['miles'] = df['remarks'].str.findall(r'[\d]+ (?i)\b(?:{})\b'.format('|'.join(miles))).apply(', '.join)

NM2 = ['NM']
df['NM2'] = df['remarks'].str.findall(r'[\d]+(?i)\b(?:{})\b'.format('|'.join(NM2))).apply(', '.join)

# %%
#check to make sure new columns added
df.head()

# %%
#write output to file

df.to_csv('/Users/Char/Desktop/lasers2.csv', index = False)
