# %% [markdown]
# Code to merge the weather data into the laser strikes. This is done by location so the script will need to be updated and run for each location. This example is for PHX (Phoenix)

# %%
import pandas as pd

# %% [markdown]
# Update the line below for the location of the METAR weather CSV file (in this case PHX)

# %%
dfW = pd.read_csv("C:/Users/PHX_201101010000_202101310000.csv")
# Out:
# C:\Users\davis\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Update the line below for the location of the laser combined file

# %%
df = pd.read_csv("C:/Users/laser_combined.csv")
# Out:
# C:\Users\davis\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (11,14,16,18,33,36,37,38,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dfL = df[(df.ncport == 'PHX')]

# %%
dfL['date2'] = pd.to_datetime(dfL.date).dt.tz_localize(None)
# Out:
# C:\Users\davis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
left = dfL.sort_values('date2')

# %%
dfW['date2'] = pd.to_datetime(dfW['valid'])

# %%
dfN = pd.merge_asof(left, dfW, on="date2")

# %%
df_mapping = pd.DataFrame({
    'skyc1': ['CLR', 'FEW', 'SCT', 'BKN', 'OVC', 'VV ', 'M'],
})
sort_mapping = df_mapping.reset_index().set_index('skyc1')
dfN['skyc1_num'] = dfN['skyc1'].map(sort_mapping['index'])
# Out:
#                           X_id                      date callsign  \
# 634   5d2de4442834ae4512063b71  2016-03-27T07:35:00.000Z   AAL636
# 468   5d2de26e2834ae451201a53f  2015-05-26T11:28:00.000Z   AAL721
# 906   5d2de2ea2834ae451202e3ba  2018-02-03T10:56:00.000Z   N880AM
# 471   5d2de2732834ae451201b1e2  2015-05-28T13:41:00.000Z  SWA1974
# 904   5d2de37b2834ae4512046544  2018-01-25T10:01:00.000Z  MSQT591
# 903   5d2de3b22834ae451204f7f3  2018-01-18T10:35:00.000Z   SWA159
# 474   5d2de3792834ae4512045dc7  2015-06-07T11:06:00.000Z   AAL425
# 902   5d2de2eb2834ae451202e668  2018-01-17T09:26:00.000Z   MSQT55
# 901   5d2de3072834ae4512032e5d  2018-01-11T09:29:00.000Z   N108ND
# 477   5d2de26d2834ae451201a015  2015-06-14T10:40:00.000Z   JBU135
# 478   5d2de27c2834ae451201cce7  2015-06-16T10:56:00.000Z  UAL1485
# 479   5d2de27e2834ae451201d1cc  2015-06-17T10:06:00.000Z  SWA4207
# 480   5d2de2812834ae451201dadd  2015-06-17T11:29:00.000Z  SKW2762
# 481   5d2de2712834ae451201aabb  2015-06-24T09:12:00.000Z   N423DM
# 900   5d2de3072834ae4512032e59  2018-01-11T08:20:00.000Z  HGT3344
# 899   5d2de3072834ae4512032e58  2018-01-11T08:18:00.000Z   BTQ817
# 898   5d2de3d82834ae4512054099  2018-01-09T07:17:00.000Z  AAL1878
# 485   5d2de27d2834ae451201cee9  2015-06-28T11:23:00.000Z  SWA4511
# 467   5d2de27e2834ae451201d0c3  2015-05-26T11:26:00.000Z  SWA3314
# 910   5d2de2ef2834ae451202f231  2018-03-04T07:18:00.000Z   DAL677
# 913   5d2de3012834ae4512031cc2  2018-03-10T11:23:00.000Z  AAL2708
# 464   5d2de27a2834ae451201c5b4  2015-05-24T10:11:00.000Z  UAL1492
# 445   5d2de4062834ae451205a750  2015-03-28T09:04:00.000Z   AWE615
# 931   5d2de3cb2834ae4512051da7  2018-05-19T10:07:00.000Z  SWA1482
# 447   5d2de27e2834ae451201d296  2015-04-08T10:46:00.000Z  SWA1250
# 930   5d2de3182834ae45120361a0  2018-05-05T10:19:00.000Z  SWA1260
# 927   5d2de3282834ae451203823e  2018-04-22T10:18:00.000Z  AAL1455
# 926   5d2de3d92834ae451205435a  2018-04-22T08:45:00.000Z  AAL1185
# 452   5d2de3af2834ae451204ef89  2015-04-27T08:38:00.000Z   AAL615
# 453   5d2de27b2834ae451201ca38  2015-04-29T11:11:00.000Z  UAL1720
# ...                        ...                       ...      ...
# 885   5d2de3872834ae45120488da  2017-11-28T08:47:00.000Z   N145WW
# 881   5d2de3082834ae4512033014  2017-11-21T07:23:00.000Z   NDU604
# 1179  5e671019d4cd0bdec7ff13ec  2020-03-10T02:12:00.000Z   RDDL20
# 878   5d2de2f52834ae4512030301  2017-11-14T17:40:00.000Z  FDX1403
# 877   5d2de2f02834ae451202f56c  2017-11-13T06:28:00.000Z  SWA3137
# 875   5d2de2f92834ae4512030fd3  2017-11-11T06:57:00.000Z   SWA342
# 1184  5e7851d4d4cd0bdec7ff6ff7  2020-03-23T04:49:00.000Z  NKS1345
# 873   5d2de4462834ae45120641e5  2017-11-06T05:00:00.000Z  SWA3089
# 911   5d2de2fe2834ae45120312da  2018-03-04T08:48:00.000Z  RDDLE34
# 1161  5e251f8e36036dad442f168e  2020-01-20T03:32:00.000Z  SWA3506
# 1160  5e23e70736036dad442f0e04  2020-01-19T05:09:00.000Z  JBU1157
# 915   5d2de2ea2834ae451202e54c  2018-03-19T12:45:00.000Z    FLCN5
# 1134  5dda1f57d32b6addd1a85d25  2019-11-24T04:50:00.000Z  SWA5098
# 939   5d2de30f2834ae45120346e3  2018-06-15T10:13:00.000Z  SWA1762
# 936   5d2de32a2834ae451203872e  2018-06-02T13:15:00.000Z   N114TL
# 933   5d2de31d2834ae4512036de9  2018-05-26T13:42:00.000Z  ASH5761
# 928   5d2de3982834ae451204b01f  2018-04-26T09:50:00.000Z  ASH5868
# 1142  5df092d7d32b6addd1a8e42f  2019-12-11T03:16:00.000Z  AAL1766
# 1143  5df1950ad32b6addd1a8eaeb  2019-12-12T01:15:00.000Z  UPS2846
# 1130  5dd0c09a11a3afb76b15e0f2  2019-11-17T03:22:00.000Z  MSQT182
# 1144  5df44fa2d32b6addd1a8fc91  2019-12-14T02:25:00.000Z  AAL1825
# 1146  5df47c89d32b6addd1a8fe0c  2019-12-14T04:34:00.000Z     TV03
# 923   5d2de4462834ae45120644a7  2018-04-16T12:42:00.000Z   ASA632
# 1148  5df739e9d32b6addd1a90e4e  2019-12-16T06:40:00.000Z  FFT2966
# 1151  5dfdf616d32b6addd1a93afd  2019-12-21T10:37:00.000Z  AAL2298
# 919   5d2de4282834ae451205f9a5  2018-03-31T10:55:00.000Z  SKW3086
# 917   5d2de2e82834ae451202dbeb  2018-03-31T09:43:00.000Z   SWA826
# 1156  5e10462136036dad442e8ecd  2020-01-04T07:59:00.000Z    FRBD9
# 1145  5df44f19d32b6addd1a8fc88  2019-12-14T02:35:00.000Z  SWA3700
# 726   5d2de2ab2834ae451202435c  2016-10-31T14:15:00.000Z   N63950
#
#                                            acType  \
# 634                           A321, AIRBUS, A-321
# 468                           A321, AIRBUS, A-321
# 906                          PC12, PILATUS, Eagle
# 471                         B737, BOEING, 737-700
# 904                         P28A, AICSA, Archer 2
# 903                         B737, BOEING, 737-700
# 474                           A321, AIRBUS, A-321
# 902                   PA44, AICSA, PA-44 Seminole
# 901                         P28A, AICSA, Archer 2
# 477                           A320, AIRBUS, A-320
# 478                         B737, BOEING, 737-700
# 479                         B737, BOEING, 737-700
# 480                CRJ2, CANADAIR, Challenger 800
# 481                         P28A, AICSA, Archer 2
# 900                      E45X, EMBRAER, EMB-145XR
# 899                          PC12, PILATUS, Eagle
# 898                           A319, AIRBUS, A-319
# 485                         B737, BOEING, 737-700
# 467                         B737, BOEING, 737-700
# 910                         B712, BOEING, 717-200
# 913                         B738, BOEING, 737-800
# 464                         B739, BOEING, 737-900
# 445                           A320, AIRBUS, A-320
# 931                         B737, BOEING, 737-700
# 447                         B737, BOEING, 737-700
# 930                         B737, BOEING, 737-700
# 927                         B737, BOEING, 737-700
# 926                         B738, BOEING, 737-800
# 452                           A320, AIRBUS, A-320
# 453                         B737, BOEING, 737-700
# ...                                           ...
# 885                   PA44, AICSA, PA-44 Seminole
# 881                             C172, CESSNA, 172
# 1179                                         C172
# 878                           MD11, BOEING, MD-11
# 877                         B737, BOEING, 737-700
# 875                         B737, BOEING, 737-700
# 1184                                         A321
# 873                         B737, BOEING, 737-700
# 911                             C172, CESSNA, 172
# 1161                                         B738
# 1160                                         A320
# 915                          H500, AGUSTA, NH-500
# 1134                                         B737
# 939                         B737, BOEING, 737-700
# 936                             C182, Cessna, 182
# 933   CRJ9, CANADAIR, CL-600 Regional Jet CRJ-705
# 928                CRJ2, CANADAIR, Challenger 800
# 1142                                         A319
# 1143                                         A306
# 1130                                         P28A
# 1144                                         A321
# 1146                                          R44
# 923                         B739, BOEING, 737-900
# 1148                                         A20N
# 1151                                         A321
# 919                CRJ7, CANADAIR, Challenger 870
# 917                         B737, BOEING, 737-700
# 1156                                         HELO
# 1145                                         B738
# 726                          PA27, CHINCUL, Aztec
#
#                                                 remarks ncport orig.faa  \
# 634    Aircraft reported cockpit illuminated by a gr...    PHX      LAX
# 468    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 906    Aircraft reported cockpit illuminated by a gr...    PHX      SLC
# 471    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 904    Aircraft reported cockpit illuminated by a gr...    PHX      VFR
# 903    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 474    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 902    Aircraft reported cockpit illuminated by a gr...    PHX      DVT
# 901    Aircraft reported cockpit illuminated by a gr...    PHX      VFR
# 477    0530, 8 miles east of PHX, at 4,000 feet, hea...    PHX      PHX
# 478    0510, 17 miles southeast of PHX, at 6,000 fee...    PHX      PHX
# 479    0451 Aircraft reported cockpit illuminated by...    PHX      SFO
# 480    0614 Aircraft reported cockpit illuminated by...    PHX      FLG
# 481    Aircraft reported cockpit illuminated by a gr...    PHX      VFR
# 900    Aircraft reported cockpit illuminated by a gr...    PHX      IWA
# 899    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 898    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 485    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 467    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 910    Aircraft reported a green LASER from theleft ...    PHX      SLC
# 913    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 464    0458 Aircraft reported cockpit illuminated by...    PHX      PHX
# 445    0322 Aircraft reported cockpit illuminated by...    PHX      NaN
# 931    Aircraft was illuminated by a green LASER fro...    PHX      PHX
# 447    0530, 15 miles west of PHX, at 10,000 feet, h...    PHX      SFO
# 930    Aircraft was illuminated by a green LASER fro...    PHX      PHX
# 927    Aircraft reported cockpit illuminated by ablu...    PHX      DTW
# 926    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 452    Aircraft reported cockpit illuminated by a gr...    PHX      NaN
# 453    Aircraft reported cockpit illuminated by a gr...    PHX      EWR
# ...                                                 ...    ...      ...
# 885    Aircraft reported cockpit illuminated by a gr...    PHX      DVT
# 881    Aircraft reported cockpit illuminated by a gr...    PHX      CGZ
# 1179   Aircraft reported cockpit illuminated by a gr...    PHX      VFR
# 878    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 877    Aircraft reported cockpit illuminated by a gr...    PHX      SEA
# 875    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 1184   Aircraft reported cockpit illuminated by a gr...    PHX      MSP
# 873    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 911    Aircraft reported cockpit illuminated by a gr...    PHX      VFR
# 1161   Aircraft reported cockpit illuminated by a gr...    PHX      MCO
# 1160   Aircraft reported cockpit illuminated by a gr...    PHX      FLL
# 915    Mesa PD aircraft reported cockpit illuminated...    PHX      VFR
# 1134   Aircraft reported cockpit illuminated by a gr...    PHX      BUR
# 939    Aircraft reported cockpit illuminated by a gr...    PHX      SNA
# 936    Aircraft reported cockpit illuminated by a gr...    PHX      SBA
# 933    Aircraft was illuminated by a green LASERwhil...    PHX      ABQ
# 928    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 1142   Aircraft reported cockpit illuminated by a gr...    PHX      AUS
# 1143   Aircraft reported cockpit illuminated by a gr...    PHX      SLC
# 1130   Aircraft reported cockpit illuminated by a gr...    PHX      DVT
# 1144   Aircraft reported cockpit illuminated by a gr...    PHX      SFO
# 1146   Aircraft was illuminated by a green LASER fro...    PHX      VFR
# 923    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 1148   Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 1151   Aircraft reported cockpit illuminated by a gr...    PHX      SMF
# 919    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 917    Aircraft reported cockpit illuminated by a gr...    PHX      PHX
# 1156   Aircraft reported cockpit illuminated by a gr...    PHX      VFR
# 1145   Aircraft reported cockpit illuminated by a gr...    PHX      OAK
# 726    Aircraft reported cockpit illuminated by a gr...    PHX      VFR
#
#      dest.faa                                 com.pat  com.cnt  ... wxcodes  \
# 634       PHX                         10 NM NW of PHX        1  ...       M
# 468       LAX                           8 NM E of PHX        1  ...       M
# 906       DVT  10 miles NNW $ 10 miles NNW of Phoenix        2  ...       M
# 471       OAK                          13NM SW of PHX        1  ...       M
# 904       VFR                           25 NMNW ofPHX        1  ...       M
# 903       MCO                            6 NM W ofPHX        1  ...       M
# 474       SEA                           10 NMNE ofPHX        1  ...       M
# 902       DVT                 4 miles west of Phoenix        1  ...       M
# 901       PHX                          3 NM SE of PHX        1  ...       M
# 477       JFK                     8 miles east of PHX        1  ...       M
# 478       IAH               17 miles southeast of PHX        1  ...       M
# 479       PHX                            5NM W of PHX        1  ...       M
# 480       PHX                         10NM WNW of PHX        1  ...       M
# 481       VFR                        3NM north of PHX        1  ...       M
# 900       SJC           4 NM SEof PHX $ 4 NM SEof PHX        2  ...       M
# 899       SOW                          4 NM SE of PHX        1  ...       M
# 898       ONT                            4 NME of PHX        1  ...       M
# 485       LAS                       10 NM West of PHX        1  ...       M
# 467       SJC                           8 NM E of PHX        1  ...       M
# 910       PHX                                     NaN        0  ...       M
# 913       LAX                         44 NMWSW of PHX        1  ...       M
# 464       IAH                   9NM E of Phoenix ARPT        1  ...       M
# 445       PHX                           20NM N of PHX        1  ...       M
# 931       PIT                           4 NM E of PHX        1  ...       M
# 447       PHX                    15 miles west of PHX        1  ...       M
# 930       SNA                         10 NM SW of PHX        1  ...       M
# 927       PHX                           8 NMSE of PHX        1  ...       M
# 926       SNA                         12 NMESE of PHX        1  ...       M
# 452       PHX                            4 NME of PHX        1  ...       M
# 453       PHX                        10NM east of PHX        1  ...       M
# ...       ...                                     ...      ...  ...     ...
# 885       VFR                                     NaN        0  ...       M
# 881       PHX                     8 NM SSW of Phoenix        1  ...       M
# 1179      VFR                           5 NM N of PHX        1  ...       M
# 878       MEM                            5NM S of PHX        1  ...       M
# 877       PHX                          12NM NW of PHX        1  ...       M
# 875       BUR                          5 NM SW of PHX        1  ...       M
# 1184      PHX                                     NaN        0  ...       M
# 873       DAL         27 NMeast of PHX $ 27 NMeast of        2  ...       M
# 911       VFR                   8 miles NW of Phoenix        1  ...       M
# 1161      PHX                          17 NM S of PHX        1  ...       M
# 1160      PHX                         25 NM SE of PHX        1  ...       M
# 915       VFR                    7 NM east of Phoenix        1  ...       M
# 1134      PHX                       25 NM West of PHX        1  ...       M
# 939       PHX                            2 NMW of PHX        1  ...       M
# 936       PHX                         10 NMNNW of PHX        1  ...       M
# 933       PHX                         16 NM NW of PHX        1  ...       M
# 928       LGB                      11 miles SW of PHX        1  ...       M
# 1142      PHX                           16NM E of PHX        1  ...       M
# 1143      PHX                        16 NM NNW of PHX        1  ...       M
# 1130      DVT                            3NM N of PHX        1  ...       M
# 1144      PHX                    9 NM East of Phoenix        1  ...       M
# 1146      VFR                          5 NM NW of PHX        1  ...       M
# 923       SEA                          6 NMNNE of PHX        1  ...       M
# 1148      EWR                         10 NM NW of PHX        1  ...       M
# 1151      PHX                          10 NM N of PHX        1  ...       M
# 919       LAX                         30 NMWSW of PHX        1  ...       M
# 917       SLC                            9 NMN of PHX        1  ...       M
# 1156      VFR                          7 NM NW of PHX        1  ...       M
# 1145      PHX                                     NaN        0  ...       M
# 726       VFR                          12 NMSE of PHX        1  ...       M
#
#      ice_accretion_1hr ice_accretion_3hr  ice_accretion_6hr peak_wind_gust  \
# 634                  M                 M                  M              M
# 468                  M                 M                  M              M
# 906                  M                 M                  M              M
# 471                  M                 M                  M              M
# 904                  M                 M                  M              M
# 903                  M                 M                  M              M
# 474                  M                 M                  M              M
# 902                  M                 M                  M              M
# 901                  M                 M                  M              M
# 477                  M                 M                  M              M
# 478                  M                 M                  M              M
# 479                  M                 M                  M              M
# 480                  M                 M                  M              M
# 481                  M                 M                  M              M
# 900                  M                 M                  M              M
# 899                  M                 M                  M              M
# 898                  M                 M                  M              M
# 485                  M                 M                  M              M
# 467                  M                 M                  M              M
# 910                  M                 M                  M              M
# 913                  M                 M                  M              M
# 464                  M                 M                  M              M
# 445                  M                 M                  M              M
# 931                  M                 M                  M              M
# 447                  M                 M                  M              M
# 930                  M                 M                  M              M
# 927                  M                 M                  M              M
# 926                  M                 M                  M              M
# 452                  M                 M                  M              M
# 453                  M                 M                  M              M
# ...                ...               ...                ...            ...
# 885                  M                 M                  M              M
# 881                  M                 M                  M              M
# 1179                 M                 M                  M              M
# 878                  M                 M                  M              M
# 877                  M                 M                  M              M
# 875                  M                 M                  M              M
# 1184                 M                 M                  M              M
# 873                  M                 M                  M              M
# 911                  M                 M                  M              M
# 1161                 M                 M                  M              M
# 1160                 M                 M                  M              M
# 915                  M                 M                  M              M
# 1134                 M                 M                  M              M
# 939                  M                 M                  M              M
# 936                  M                 M                  M              M
# 933                  M                 M                  M              M
# 928                  M                 M                  M              M
# 1142                 M                 M                  M              M
# 1143                 M                 M                  M              M
# 1130                 M                 M                  M              M
# 1144                 M                 M                  M              M
# 1146                 M                 M                  M              M
# 923                  M                 M                  M              M
# 1148                 M                 M                  M              M
# 1151                 M                 M                  M              M
# 919                  M                 M                  M              M
# 917                  M                 M                  M              M
# 1156                 M                 M                  M              M
# 1145                 M                 M                  M              M
# 726                  M                 M                  M              M
#
#      peak_wind_drct peak_wind_time   feel  \
# 634               M              M  66.92
# 468               M              M  71.52
# 906               M              M      M
# 471               M              M  69.27
# 904               M              M      M
# 903               M              M      M
# 474               M              M  75.92
# 902               M              M      M
# 901               M              M      M
# 477               M              M  85.47
# 478               M              M   84.7
# 479               M              M  96.98
# 480               M              M  86.52
# 481               M              M  90.44
# 900               M              M      M
# 899               M              M      M
# 898               M              M      M
# 485               M              M  89.96
# 467               M              M  71.52
# 910               M              M      M
# 913               M              M      M
# 464               M              M  69.45
# 445               M              M  69.08
# 931               M              M      M
# 447               M              M  66.92
# 930               M              M      M
# 927               M              M      M
# 926               M              M      M
# 452               M              M  60.08
# 453               M              M  71.64
# ...             ...            ...    ...
# 885               M              M      M
# 881               M              M      M
# 1179              M              M      M
# 878               M              M      M
# 877               M              M      M
# 875               M              M      M
# 1184              M              M      M
# 873               M              M      M
# 911               M              M      M
# 1161              M              M      M
# 1160              M              M      M
# 915               M              M      M
# 1134              M              M      M
# 939               M              M      M
# 936               M              M      M
# 933               M              M      M
# 928               M              M      M
# 1142              M              M      M
# 1143              M              M      M
# 1130              M              M      M
# 1144              M              M      M
# 1146              M              M      M
# 923               M              M      M
# 1148              M              M      M
# 1151              M              M      M
# 919               M              M      M
# 917               M              M      M
# 1156              M              M      M
# 1145              M              M      M
# 726               M              M      M
#
#                                                   metar  skyc1_num
# 634   KPHX 270651Z 25007KT 10SM CLR 19/M10 A2989 RMK...          0
# 468   KPHX 261051Z 00000KT 10SM CLR 23/05 A2989 RMK ...          0
# 906   KPHX 031055Z AUTO 09004KT 10SM CLR 12/M03 A300...          0
# 471   KPHX 281251Z 12004KT 10SM CLR 22/03 A2990 RMK ...          0
# 904   KPHX 251000Z AUTO 00000KT 10SM CLR 09/M07 A300...          0
# 903   KPHX 181035Z AUTO 00000KT 10SM CLR 10/M02 A301...          0
# 474   KPHX 071051Z 06006KT 10SM CLR 24/09 A2980 RMK ...          0
# 902   KPHX 170925Z AUTO 13006KT 10SM CLR 13/M03 A301...          0
# 901   KPHX 110925Z AUTO 00000KT 10SM CLR 11/09 A3009...          0
# 477   KPHX 140951Z 30007KT 10SM CLR 32/06 A2965 RMK ...          0
# 478   KPHX 161051Z 00000KT 10SM CLR 31/07 A2978 RMK ...          0
# 479   KPHX 170351Z 24006KT 10SM CLR 39/04 A2974 RMK ...          0
# 480   KPHX 171051Z 14004KT 10SM CLR 32/08 A2980 RMK ...          0
# 481   KPHX 240851Z 13005KT 10SM CLR 35/03 A2976 RMK ...          0
# 900   KPHX 110820Z AUTO 08003KT 10SM CLR 12/09 A3007...          0
# 899   KPHX 110815Z AUTO 07004KT 10SM CLR 12/09 A3008...          0
# 898   KPHX 090715Z AUTO 08005KT 10SM CLR 17/02 A2992...          0
# 485   KPHX 281051Z 00000KT 10SM CLR 32/16 A2988 RMK ...          0
# 467   KPHX 261051Z 00000KT 10SM CLR 23/05 A2989 RMK ...          0
# 910   KPHX 040715Z AUTO 09004KT 10SM CLR 17/M02 A299...          0
# 913   KPHX 101120Z AUTO /////KT 10SM CLR 18/M01 A298...          0
# 464   KPHX 240951Z 01003KT 10SM CLR 22/05 A2987 RMK ...          0
# 445   KPHX 280851Z 12005KT 10SM CLR 21/M01 A3000 RMK...          0
# 931   KPHX 191005Z AUTO 33004G00KT 10SM CLR 25/M01 A...          0
# 447   KPHX 080951Z 26011KT 10SM CLR 19/M05 A2985 RMK...          0
# 930   KPHX 051015Z AUTO 00000G00KT 10SM CLR 23/M02 A...          0
# 927   KPHX 221015Z AUTO 09006KT 10SM CLR 21/03 A2988...          0
# 926   KPHX 220845Z AUTO 12005KT 10SM CLR 22/02 A2990...          0
# 452   KPHX 270751Z 00000KT 10SM CLR 16/10 A2985 RMK ...          0
# 453   KPHX 291051Z 12006KT 10SM CLR 23/06 A2994 RMK ...          0
# ...                                                 ...        ...
# 885    KPHX 280845Z AUTO 27007KT 10SM A2989 RMK MADISHF          6
# 881    KPHX 210720Z AUTO 09003KT 10SM A3002 RMK MADISHF          6
# 1179  KPHX 100210Z AUTO 00000KT 10SM 23/03 A3003 RMK...          6
# 878    KPHX 141740Z AUTO 09006KT 10SM A3004 RMK MADISHF          6
# 877    KPHX 130625Z AUTO 09006KT 10SM A3000 RMK MADISHF          6
# 875    KPHX 110655Z AUTO 10004KT 10SM A2989 RMK MADISHF          6
# 1184  KPHX 230445Z AUTO 29005KT 10SM 21/02 A3001 RMK...          6
# 873    KPHX 060500Z AUTO 31007KT 10SM A2999 RMK MADISHF          6
# 911   KPHX 040845Z AUTO 00000KT 10SM 14/M01 A2997 RM...          6
# 1161  KPHX 200330Z AUTO 00000KT 10SM 17/01 A3007 RMK...          6
# 1160  KPHX 190505Z AUTO 21002KT 10SM 13/00 A3014 RMK...          6
# 915   KPHX 191245Z AUTO 22004KT 10SM 11/M02 A3003 RM...          6
# 1134  KPHX 240450Z AUTO 00000KT 10SM 15/07 A3005 RMK...          6
# 939   KPHX 151010Z AUTO 00000G00KT 10SM 32/12 A2971 ...          6
# 936   KPHX 021315Z AUTO 10005G00KT 10SM 24/03 A2987 ...          6
# 933   KPHX 261340Z AUTO 09004G00KT 10SM 23/03 A2982 ...          6
# 928   KPHX 260950Z AUTO 26003KT 10SM 26/M01 A2982 RM...          6
# 1142  KPHX 110315Z AUTO 24002KT 10SM 14/06 A3019 RMK...          6
# 1143  KPHX 120115Z AUTO 28007KT 10SM 18/04 A3009 RMK...          6
# 1130  KPHX 170320Z AUTO 00000KT 10SM 19/01 A2995 RMK...          6
# 1144  KPHX 140225Z AUTO 21002KT 10SM 16/07 A2998 RMK...          6
# 1146  KPHX 140430Z AUTO 11004KT 10SM 14/08 A2998 RMK...          6
# 923   KPHX 161240Z AUTO /////KT 10SM 18/M08 A2986 RM...          6
# 1148  KPHX 160640Z AUTO 00000KT 10SM 10/00 A3004 RMK...          6
# 1151  KPHX 211035Z AUTO 12005KT 10SM 07/M01 A3026 RM...          6
# 919   KPHX 311055Z AUTO 09005KT 10SM 18/M02 A2997 RM...          6
# 917   KPHX 310940Z AUTO 00000KT 10SM 19/M01 A2997 RM...          6
# 1156  KPHX 040755Z AUTO 11005KT 10SM 08/02 A3029 RMK...          6
# 1145  KPHX 140235Z AUTO 00000KT 10SM 16/07 A3000 RMK...          6
# 726   KPHX 311415Z AUTO 09007KT 10SM 20/08 A2991 RMK...          6
#
# [1269 rows x 80 columns]

# %%
dfN = dfN.sort_values('skyc1_num')

# %%
dfN.to_csv(r'C:/Users/davis/Documents/DAEN 690/combined_PHX.csv', index = False)

# %% [markdown]
# The lines below create a graphic of the cloud coverage.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
colors = {'CLR': "#E69F00", 'FEW': "#56B4E9", 'SCT': "#009E73", 'BKN': "#F0E442", 'OVC': "#CC79A7", 'M': "#0072B2", 'VV ': "#000000"}

# %%
sns.countplot(x ='skyc1', data = dfN, palette = colors)
plt.xlabel('Cloud Coverage Categories')
plt.ylabel('Count by Laser Strike Incident')
plt.title('Cloud Coverage for Strikes near PHX')
# Out:
# Text(0.5, 1.0, 'Cloud Coverage for Strikes near PHX')
